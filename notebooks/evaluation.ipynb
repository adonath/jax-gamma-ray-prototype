# %%
import pandas as pd

# %%
data = pd.read_csv("../results/performance-n-sources.csv")

# %%
data
# Out:
#    n_sources          gp        jax    jax-jit
# 0          1    3.837691   3.116149   2.690944
# 1          2    5.674621   3.906171   3.243003
# 2          4    9.113214   5.518192   3.767024
# 3          8   14.751984  10.056175   6.393489
# 4         16   29.036073  22.163434  10.415021
# 5         32   55.452714  37.867590  20.465326
# 6         64  108.927383  76.376536  37.898609

# %%
data.plot(x="n_sources", y=["gp", "jax", "jax-jit"], kind="line", title="Time vs. Number of Sources", ylabel="")
# Out:
# <Axes: title={'center': 'Time vs. Number of Sources'}, xlabel='n_sources'>
